# %% [markdown]
# ### Difference between Normalized and Un Normalized Data
#
# ### Normal Color
#
#
# Training Accuracy = 0.978
# Validation Accuracy = 0.918
# ![Normal_color.png](./Normal_color.png)
#
# ### Normalized Color
#
# Training Accuracy = 0.991
# Validation Accuracy = 0.810
# ![Normalize_colored.png](./Normalize_colored.png)
#
# ### Grayscale
#
# Training Accuracy = 0.960
# Validation Accuracy = 0.880
#
# ![grayscale_color.png](./grayscale_color.png)
#
# ### Normalized Grayscale
#
# Training Accuracy = 0.996
# Validation Accuracy = 0.648
#
# Training Accuracy = 0.995
# Validation Accuracy = 0.816
#
# ![normalized_grayscale_color.png](./normalized_grayscale_color.png)
#
# ### Histogram
#
# Training Accuracy = 0.968
# Validation Accuracy = 0.880
#
# ![histogram_color.png](./histogram_color.png)
#
#
# ### Normalized Histogram
#
#
# Training Accuracy = 0.999
# Validation Accuracy = 0.887
#
# ![normalized_histogram_color.png](./normalized_histogram_color.png)

# %% [markdown]
# ## Picking the preprocessed data
# ---
#
# ### 30 Epochs 128 batch size, and 0.001
#
#
# Color:
#
# Training Accuracy = 77%
# Validation Accuracy = 72%
#
# 38-64-128  512-256
#
# Training Accuracy = 97.5%
# Validation Accuracy = 90.4%
#
# ![Color.png](./Color_30.png)
#
# Normalized Color:
#
# Training Accuracy = 81%
# Validation Accuracy = 73%
#
#
# 38-64-128  512-256
#
# Training Accuracy = 98.2%
# Validation Accuracy = 92.1%
#
#
# ![Normalized%20Color.png](attachment:Normalized%20Color.png)
#
# ![NormalizedColor.png](./Normalized%20Color_30_w.png)
#
# Grayscale:
#
# Training Accuracy = 81%
# Validation Accuracy = 62%
#
#
# 38-64-128  512-256
#
# Training Accuracy = 96.2%
# Validation Accuracy = 80.6%
#
# ![Grayscale.png](attachment:Grayscale.png)
# ![Grayscale_w.png](./Grayscale_30_w.png)
#
# Histogram Equalization (Grayscale):
#
# Training Accuracy = 89%
# Validation Accuracy = 79%
#
# 38-64-128  512-256
#
# Training Accuracy = 97.5 %
# Validation Accuracy = 83.0%
#
# ![Histogram%20Equalization_30.png](attachment:Histogram%20Equalization_30.png)
# ![Histogram%20Equalization_30_w.png](attachment:Histogram%20Equalization_30_w.png)
#
# ---
#
#
#
#
#
#
# ### 50 Epochs 128 batch size, and 0.001
#
# Color:
#
# Training Accuracy = 91%
# Validation Accuracy = 85%
#
# 38-64-128  512-256
#
# ![Color_50.png](attachment:Color_50.png)
#
# Normalized Color:
#
# Training Accuracy = 92%
# Validation Accuracy = 84%
#
# 38-64-128  512-256
#
# ![Normalized%20Color_50.png](attachment:Normalized%20Color_50.png)
#
# Grayscale:
#
# Training Accuracy = 86%
# Validation Accuracy = 75%
#
# 38-64-128  512-256
#
# ![Histogram%20Equalization_50.png](attachment:Histogram%20Equalization_50.png)
#
#
# Histogram Equalization (Grayscale):
#
# 38-64-128  512-256
#
#
# Training Accuracy = 90%
# Validation Accuracy = 76%
#
# ![Histogram%20Equalization.png](attachment:Histogram%20Equalization_50.png)

# %% [markdown]
# |    Type        |          30 Epochs          |          50 Epochs          |
# | ------------     |:---------------:|:---------------:|
# | Color         |Training Accuracy = 77% Validation Accuracy = 72% |Training Accuracy = 91% Validation Accuracy = 85% |
# |Normalized Color|Training Accuracy = 81% Validation Accuracy = 73%|Training Accuracy = 92% Validation Accuracy = 84% |
# |Grayscale|Training Accuracy = 81% Validation Accuracy = 62% |Training Accuracy = 86% Validation Accuracy = 75|
# |Histogram Equalization|Training Accuracy = 89% Validation Accuracy = 79%|Training Accuracy = 90% Validation Accuracy = 76% |

# %% [markdown]
# ## Model Optimization
#
# ### Dropout to the Convlayers
#
# ### Adding Batch normalization
#
# ### Data Augmentation
